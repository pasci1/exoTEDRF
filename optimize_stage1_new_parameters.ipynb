# %%
# 1) ensure we’re in the repo root
# %cd ~/hard_disk/exoTEDRF_fork
# !pwd
# !ls

# 2) add repo-root to PYTHONPATH
import sys, os
sys.path.insert(0, os.getcwd())

import os

# point CRDS at your Optimize_WASP39b cache
os.environ['CRDS_PATH']       = os.path.join(os.getcwd(), 'Optimize_WASP39b', 'crds_cache')
os.environ['CRDS_SERVER_URL'] = 'https://jwst-crds.stsci.edu'
# force CRDS to use your locally‐cached pmap
os.environ['CRDS_CONTEXT']    = 'jwst_1322.pmap'

print("CRDS_PATH:   ", os.environ['CRDS_PATH'])
print("CRDS_SERVER_URL:", os.environ['CRDS_SERVER_URL'])
print("CRDS_CONTEXT:", os.environ['CRDS_CONTEXT'])

# from your notebook, still in /data/pascal/exoTEDRF_fork
# !find . -maxdepth 2 -name "optimize_new_parameters.py"
# Out:
# /data/pascal/exoTEDRF_fork
# /data/pascal/exoTEDRF_fork
# changelog.md		     joss
# Check_install_fork.ipynb     LICENSE
# Cost_function_5h.txt	     Optimizer_V2_test.ipynb
# Cost_function_allstages.txt  optimize_stage1.ipynb
# Cost_function.txt	     optimize_stage1_new_parameters.ipynb
# Cost_function_V2.txt	     Optimize_WASP39b
# docs			     pipeline_outputs_directory
# exoenv_fork		     README.md
# exotedrf		     readthedocs.yaml
# exotedrf.egg-info	     setup.py
# __init__.py		     WASP39b_test
# /data/pascal/exoTEDRF_fork/exoenv_fork/lib/python3.10/site-packages/IPython/core/magics/osm.py:393: UserWarning: This is now an optional IPython functionality, using bookmarks requires you to install the `pickleshare` library.
#   bkms = self.shell.db.get('bookmarks', {})
# /data/pascal/exoTEDRF_fork/exoenv_fork/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# CRDS_PATH:    /data/pascal/exoTEDRF_fork/Optimize_WASP39b/crds_cache
# CRDS_SERVER_URL: https://jwst-crds.stsci.edu
# CRDS_CONTEXT: jwst_1322.pmap
# ./exotedrf/optimize_new_parameters.py

# %%
# Assuming it’s under exotedrf/
# !python3 exotedrf/optimize_new_parameters.py --config Optimize_WASP39b/run_WASP39b.yaml

from IPython.display import Javascript

def notify():
    display(Javascript('alert("Notebook cell finished!")'))

notify()
# Out:
# → Optimizing time_window (others fixed = {{'box_size': 15, 'rejection_threshold': 15, 'time_rejection_threshold': 15, 'nirspec_mask_width': 15, 'w1': 1.0, 'w2': 1.0, 'w3': 1.0}})
# Running with params: {'time_window': 3, 'box_size': 15, 'rejection_threshold': 15, 'time_rejection_threshold': 15, 'nirspec_mask_width': 15, 'w1': 1.0, 'w2': 1.0, 'w3': 1.0}
# start running Stage 1 from Fork
# 2025-07-10 11:40:15.979 - exoTEDRF - INFO - **Starting exoTEDRF Stage 1**
# 2025-07-10 11:40:15.979 - exoTEDRF - INFO - Detector level processing
# 2025-07-10 11:40:15.984 - exoTEDRF - WARNING - Setting "save_results=False" can be memory intensive.
# 2025-07-10 11:40:15,987 - stpipe.DQInitStep - INFO - DQInitStep instance created.
# 2025-07-10 11:40:16,423 - stpipe.DQInitStep - INFO - DQInitStep instance created.
# 2025-07-10 11:40:16,675 - stpipe.DQInitStep - INFO - Step DQInitStep running with args (<Level1bModel(60, 70, 32, 2048) from jw01366003001_04101_00001-seg001_nrs1_uncal.fits>,).
# 2025-07-10 11:40:16,676 - stpipe.DQInitStep - INFO - Step DQInitStep parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ./pipeline_outputs_directory/Stage1/
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: False
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
# 2025-07-10 11:40:17,105 - stpipe.DQInitStep - INFO - Using MASK reference file /data/pascal/exoTEDRF_fork/Optimize_WASP39b/crds_cache/references/jwst/nirspec/jwst_nirspec_mask_0051.fits
# 2025-07-10 11:40:18,077 - stpipe.DQInitStep - INFO - Extracting mask subarray to match science data
# 2025-07-10 11:40:18,985 - stpipe.DQInitStep - INFO - Results used CRDS context: jwst_1322.pmap
# 2025-07-10 11:40:18,985 - stpipe.DQInitStep - INFO - Step DQInitStep done
# 2025-07-10 11:40:18,985 - stpipe - INFO - Results used jwst version: 1.17.1
# 2025-07-10 11:40:18.985 - exoTEDRF - WARNING - EmiCorrStep not supported for NIRSpec/PRISM.
# 2025-07-10 11:40:18.985 - exoTEDRF - WARNING - Setting "save_results=False" can be memory intensive.
# 2025-07-10 11:40:18,986 - stpipe.SaturationStep - INFO - SaturationStep instance created.
# 2025-07-10 11:40:18,996 - stpipe.SaturationStep - INFO - SaturationStep instance created.
# 2025-07-10 11:40:19,216 - stpipe.SaturationStep - INFO - Step SaturationStep running with args (<RampModel(60, 70, 32, 2048) from jw01366003001_04101_00001-seg001_nrs1_uncal.fits>,).
# 2025-07-10 11:40:19,218 - stpipe.SaturationStep - INFO - Step SaturationStep parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ./pipeline_outputs_directory/Stage1/
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: False
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   n_pix_grow_sat: 1
#   use_readpatt: True
# 2025-07-10 11:40:19,229 - stpipe.SaturationStep - INFO - Using SATURATION reference file /data/pascal/exoTEDRF_fork/Optimize_WASP39b/crds_cache/references/jwst/nirspec/jwst_nirspec_saturation_0028.fits
# 2025-07-10 11:40:20,092 - stpipe.SaturationStep - INFO - Extracting reference file subarray to match science data
# 2025-07-10 11:40:20,099 - stpipe.SaturationStep - INFO - Using read_pattern with nframes 1
# 2025-07-10 11:40:28,760 - stpipe.SaturationStep - INFO - Detected 320 saturated pixels
# 2025-07-10 11:40:28,984 - stpipe.SaturationStep - INFO - Detected 0 A/D floor pixels
# 2025-07-10 11:40:28,989 - stpipe.SaturationStep - INFO - Results used CRDS context: jwst_1322.pmap
# 2025-07-10 11:40:28,989 - stpipe.SaturationStep - INFO - Step SaturationStep done
# 2025-07-10 11:40:28,989 - stpipe - INFO - Results used jwst version: 1.17.1
# 2025-07-10 11:40:28.989 - exoTEDRF - WARNING - ResetStep not supported for NIRSpec/PRISM.
# 2025-07-10 11:40:29.007 - exoTEDRF - WARNING - Setting "save_results=False" can be memory intensive.
# 2025-07-10 11:40:29,008 - stpipe.SuperBiasStep - INFO - SuperBiasStep instance created.
# 2025-07-10 11:40:29,015 - stpipe.SuperBiasStep - INFO - SuperBiasStep instance created.
# 2025-07-10 11:40:29,211 - stpipe.SuperBiasStep - INFO - Step SuperBiasStep running with args (<RampModel(60, 70, 32, 2048) from jw01366003001_04101_00001-seg001_nrs1_uncal.fits>,).
# 2025-07-10 11:40:29,212 - stpipe.SuperBiasStep - INFO - Step SuperBiasStep parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ./pipeline_outputs_directory/Stage1/
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: False
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
# 2025-07-10 11:40:29,225 - stpipe.SuperBiasStep - INFO - Using SUPERBIAS reference file /data/pascal/exoTEDRF_fork/Optimize_WASP39b/crds_cache/references/jwst/nirspec/jwst_nirspec_superbias_0427.fits
# 2025-07-10 11:40:31,977 - stpipe.SuperBiasStep - INFO - Results used CRDS context: jwst_1322.pmap
# 2025-07-10 11:40:31,977 - stpipe.SuperBiasStep - INFO - Step SuperBiasStep done
# 2025-07-10 11:40:31,977 - stpipe - INFO - Results used jwst version: 1.17.1
# 2025-07-10 11:40:31.977 - exoTEDRF - WARNING - RefPixStep not supported for NIRSpec/PRISM.
# 2025-07-10 11:40:31.998 - exoTEDRF - WARNING - Setting "save_results=False" can be memory intensive.
# 2025-07-10 11:40:31,999 - stpipe.DarkCurrentStep - INFO - DarkCurrentStep instance created.
# 2025-07-10 11:40:32,006 - CRDS - ERROR -  Error determining best reference for 'pars-darkcurrentstep'  =   No match found.
# 2025-07-10 11:40:32,006 - stpipe.DarkCurrentStep - INFO - DarkCurrentStep instance created.
# 2025-07-10 11:40:32,219 - stpipe.DarkCurrentStep - INFO - Step DarkCurrentStep running with args (<RampModel(60, 70, 32, 2048) from jw01366003001_04101_00001-seg001_nrs1_uncal.fits>,).
# 2025-07-10 11:40:32,221 - stpipe.DarkCurrentStep - INFO - Step DarkCurrentStep parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ./pipeline_outputs_directory/Stage1/
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: False
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   dark_output: None
#   average_dark_current: None
# 2025-07-10 11:40:32,233 - stpipe.DarkCurrentStep - INFO - Using DARK reference file /data/pascal/exoTEDRF_fork/Optimize_WASP39b/crds_cache/references/jwst/nirspec/jwst_nirspec_dark_0438.fits
# 2025-07-10 11:40:33,361 - stpipe.DarkCurrentStep - INFO - Science data nints=60, ngroups=70, nframes=1, groupgap=0
# 2025-07-10 11:40:33,361 - stpipe.DarkCurrentStep - INFO - Dark data nints=1, ngroups=70, nframes=1, groupgap=0
# 2025-07-10 11:40:34,884 - stpipe.DarkCurrentStep - INFO - Results used CRDS context: jwst_1322.pmap
# 2025-07-10 11:40:34,885 - stpipe.DarkCurrentStep - INFO - Step DarkCurrentStep done
# 2025-07-10 11:40:34,885 - stpipe - INFO - Results used jwst version: 1.17.1
# 2025-07-10 11:40:34.909 - exoTEDRF - WARNING - Setting "save_results=False" can be memory intensive.
# 2025-07-10 11:40:34.909 - exoTEDRF - INFO - OneOverFStep instance created.
# 2025-07-10 11:40:34.909 - exoTEDRF - INFO - Creating reference deep stack.
# 2025-07-10 11:40:39.071 - exoTEDRF - INFO - No centroids provided, locating trace positions.
# 2025-07-10 11:40:39.095 - exoTEDRF - INFO - Starting 1/f correction step using the median method.
# 2025-07-10 11:40:39.095 - exoTEDRF - INFO - Processing file jw01366003001_04101_00001-seg001_nrs1_uncal.fits.
# 2025-07-10 11:40:39.095 - exoTEDRF - INFO - Unpacking centroids.
# 2025-07-10 11:40:39.095 - exoTEDRF - WARNING - Dimension of passed centroids do not match data frame dimensions. New centroids will be calculated.
# 2025-07-10 11:40:39.161 - exoTEDRF - WARNING - No outlier map passed, ignoring outliers.
# 2025-07-10 11:40:39.168 - exoTEDRF - INFO - Constructing trace mask.
# 2025-07-10 11:40:39.187 - exoTEDRF - INFO - Flagging additional outliers.
# 2025-07-10 11:40:39.409 - exoTEDRF - INFO - Starting full frame correction.
# 100%|███████████████████████████████████████████| 60/60 [00:03<00:00, 18.91it/s]
# 2025-07-10 11:40:43.041 - exoTEDRF - INFO - Step OneOverFStep done.
# 2025-07-10 11:40:43.049 - exoTEDRF - WARNING - Setting "save_results=False" can be memory intensive.
# 2025-07-10 11:40:43,050 - stpipe.LinearityStep - INFO - LinearityStep instance created.
# 2025-07-10 11:40:43,056 - stpipe.LinearityStep - INFO - LinearityStep instance created.
# 2025-07-10 11:40:43,270 - stpipe.LinearityStep - INFO - Step LinearityStep running with args (<RampModel(60, 70, 32, 2048) from jw01366003001_04101_00001-seg001_nrs1_uncal.fits>,).
# 2025-07-10 11:40:43,272 - stpipe.LinearityStep - INFO - Step LinearityStep parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ./pipeline_outputs_directory/Stage1/
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: False
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
# 2025-07-10 11:40:43,283 - stpipe.LinearityStep - INFO - Using Linearity reference file /data/pascal/exoTEDRF_fork/Optimize_WASP39b/crds_cache/references/jwst/nirspec/jwst_nirspec_linearity_0024.fits
# 2025-07-10 11:40:43,307 - stpipe.LinearityStep - WARNING - Keyword BAD_LIN_CORR does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-07-10 11:40:45,476 - stpipe.LinearityStep - INFO - Results used CRDS context: jwst_1322.pmap
# 2025-07-10 11:40:45,477 - stpipe.LinearityStep - INFO - Step LinearityStep done
# 2025-07-10 11:40:45,477 - stpipe - INFO - Results used jwst version: 1.17.1
# 2025-07-10 11:40:45.500 - exoTEDRF - INFO - Starting time-domain jump detection step.
# 2025-07-10 11:40:45.500 - exoTEDRF - INFO - Processing file jw01366003001_04101_00001-seg001_nrs1_uncal.fits.
# 100%|███████████████████████████████████████████| 70/70 [01:32<00:00,  1.31s/it]
# 2025-07-10 11:42:17.583 - exoTEDRF - INFO - 364763 jumps flagged
# 2025-07-10 11:42:17.583 - exoTEDRF - INFO - and 0 interpolated
# 2025-07-10 11:42:17.585 - exoTEDRF - INFO - Done
# 2025-07-10 11:42:17.588 - exoTEDRF - INFO - Step JumpStep done.
# 2025-07-10 11:42:17,596 - stpipe.RampFitStep - INFO - RampFitStep instance created.
# 2025-07-10 11:42:17,602 - stpipe.RampFitStep - INFO - RampFitStep instance created.
# 2025-07-10 11:42:17,813 - stpipe.RampFitStep - INFO - Step RampFitStep running with args (<RampModel(60, 70, 32, 2048) from jw01366003001_04101_00001-seg001_nrs1_uncal.fits>,).
# 2025-07-10 11:42:17,815 - stpipe.RampFitStep - INFO - Step RampFitStep parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ./pipeline_outputs_directory/Stage1/
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: False
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   algorithm: OLS_C
#   int_name: ''
#   save_opt: False
#   opt_name: ''
#   suppress_one_group: True
#   maximum_cores: quarter
# 2025-07-10 11:42:18,985 - stpipe.RampFitStep - INFO - Using READNOISE reference file: /data/pascal/exoTEDRF_fork/Optimize_WASP39b/crds_cache/references/jwst/nirspec/jwst_nirspec_readnoise_0043.fits
# 2025-07-10 11:42:18,985 - stpipe.RampFitStep - INFO - Using GAIN reference file: /data/pascal/exoTEDRF_fork/Optimize_WASP39b/crds_cache/references/jwst/nirspec/jwst_nirspec_gain_0025.fits
# 2025-07-10 11:42:19,007 - stpipe.RampFitStep - INFO - Extracting gain subarray to match science data
# 2025-07-10 11:42:19,007 - stpipe.RampFitStep - INFO - Extracting readnoise subarray to match science data
# 2025-07-10 11:42:19,007 - stpipe.RampFitStep - INFO - Using algorithm = OLS_C
# 2025-07-10 11:42:19,007 - stpipe.RampFitStep - INFO - Using weighting = optimal
# 2025-07-10 11:42:23,860 - stpipe.RampFitStep - INFO - Number of multiprocessing slices: 8
# 2025-07-10 11:42:23,862 - stpipe.RampFitStep - INFO - Number of processors used for multiprocessing: 8
# 2025-07-10 11:42:31,325 - stpipe - INFO - Ramp Fitting C Time: 3.22420072555542
# 2025-07-10 11:42:32,537 - stpipe - INFO - Ramp Fitting C Time: 3.7919204235076904
# 2025-07-10 11:42:33,320 - stpipe - INFO - Ramp Fitting C Time: 3.956501007080078
# 2025-07-10 11:42:34,745 - stpipe - INFO - Ramp Fitting C Time: 3.824760675430298
# 2025-07-10 11:42:35,736 - stpipe - INFO - Ramp Fitting C Time: 4.233975172042847
# 2025-07-10 11:42:35,923 - stpipe - INFO - Ramp Fitting C Time: 3.397357225418091
# 2025-07-10 11:42:36,284 - stpipe - INFO - Ramp Fitting C Time: 6.087932109832764
# 2025-07-10 11:42:37,825 - stpipe - INFO - Ramp Fitting C Time: 4.492883205413818
# 2025-07-10 11:42:38,986 - stpipe.RampFitStep - INFO - Results used CRDS context: jwst_1322.pmap
# 2025-07-10 11:42:38,987 - stpipe.RampFitStep - INFO - Results used CRDS context: jwst_1322.pmap
# 2025-07-10 11:42:38,987 - stpipe.RampFitStep - INFO - Step RampFitStep done
# 2025-07-10 11:42:38,987 - stpipe - INFO - Results used jwst version: 1.17.1
# 2025-07-10 11:42:38.987 - exoTEDRF - INFO - Doing cosmetic NaN interpolation.
# 2025-07-10 11:42:40.512 - exoTEDRF - INFO - Step RampFitStep really done.
# 2025-07-10 11:42:40,529 - stpipe.GainScaleStep - INFO - GainScaleStep instance created.
# 2025-07-10 11:42:40,538 - stpipe.GainScaleStep - INFO - GainScaleStep instance created.
# 2025-07-10 11:42:40,722 - stpipe.GainScaleStep - INFO - Step GainScaleStep running with args (<CubeModel(60, 32, 2048) from jw01366003001_04101_00001-seg001_nrs1_uncal.fits>,).
# 2025-07-10 11:42:40,723 - stpipe.GainScaleStep - INFO - Step GainScaleStep parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ./pipeline_outputs_directory/Stage1/
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: False
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
# 2025-07-10 11:42:40,769 - stpipe.GainScaleStep - INFO - Rescaling by 1.429
# 2025-07-10 11:42:40,785 - stpipe.GainScaleStep - INFO - Step GainScaleStep done
# 2025-07-10 11:42:40,785 - stpipe - INFO - Results used jwst version: 1.17.1
# finish running Stage 1 from Fork
#
#
#
# ###########################################################
#  Step: 1/15 completed
# ###########################################################
#
#
#
#    time_window=3 → J=0.851452 (144.8s)
# Running with params: {'time_window': 5, 'box_size': 15, 'rejection_threshold': 15, 'time_rejection_threshold': 15, 'nirspec_mask_width': 15, 'w1': 1.0, 'w2': 1.0, 'w3': 1.0}
# start running Stage 1 from Fork
# 2025-07-10 11:42:40.794 - exoTEDRF - INFO - **Starting exoTEDRF Stage 1**
# 2025-07-10 11:42:40.794 - exoTEDRF - INFO - Detector level processing
# 2025-07-10 11:42:40.810 - exoTEDRF - WARNING - Setting "save_results=False" can be memory intensive.
# 2025-07-10 11:42:40,811 - stpipe.DQInitStep - INFO - DQInitStep instance created.
# 2025-07-10 11:42:40,817 - stpipe.DQInitStep - INFO - DQInitStep instance created.
# 2025-07-10 11:42:40,999 - stpipe.DQInitStep - INFO - Step DQInitStep running with args (<Level1bModel(60, 70, 32, 2048) from jw01366003001_04101_00001-seg001_nrs1_uncal.fits>,).
# 2025-07-10 11:42:41,001 - stpipe.DQInitStep - INFO - Step DQInitStep parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ./pipeline_outputs_directory/Stage1/
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: False
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
# 2025-07-10 11:42:41,019 - stpipe.DQInitStep - INFO - Using MASK reference file /data/pascal/exoTEDRF_fork/Optimize_WASP39b/crds_cache/references/jwst/nirspec/jwst_nirspec_mask_0051.fits
# 2025-07-10 11:42:42,032 - stpipe.DQInitStep - INFO - Extracting mask subarray to match science data
# 2025-07-10 11:42:42,717 - stpipe.DQInitStep - INFO - Results used CRDS context: jwst_1322.pmap
# 2025-07-10 11:42:42,718 - stpipe.DQInitStep - INFO - Step DQInitStep done
# 2025-07-10 11:42:42,718 - stpipe - INFO - Results used jwst version: 1.17.1
# 2025-07-10 11:42:42.718 - exoTEDRF - WARNING - EmiCorrStep not supported for NIRSpec/PRISM.
# 2025-07-10 11:42:42.718 - exoTEDRF - WARNING - Setting "save_results=False" can be memory intensive.
# 2025-07-10 11:42:42,719 - stpipe.SaturationStep - INFO - SaturationStep instance created.
# 2025-07-10 11:42:42,728 - stpipe.SaturationStep - INFO - SaturationStep instance created.
# 2025-07-10 11:42:42,910 - stpipe.SaturationStep - INFO - Step SaturationStep running with args (<RampModel(60, 70, 32, 2048) from jw01366003001_04101_00001-seg001_nrs1_uncal.fits>,).
# 2025-07-10 11:42:42,912 - stpipe.SaturationStep - INFO - Step SaturationStep parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ./pipeline_outputs_directory/Stage1/
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: False
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   n_pix_grow_sat: 1
#   use_readpatt: True
# 2025-07-10 11:42:42,925 - stpipe.SaturationStep - INFO - Using SATURATION reference file /data/pascal/exoTEDRF_fork/Optimize_WASP39b/crds_cache/references/jwst/nirspec/jwst_nirspec_saturation_0028.fits
# 2025-07-10 11:42:43,836 - stpipe.SaturationStep - INFO - Extracting reference file subarray to match science data
# 2025-07-10 11:42:43,843 - stpipe.SaturationStep - INFO - Using read_pattern with nframes 1
# 2025-07-10 11:42:52,330 - stpipe.SaturationStep - INFO - Detected 320 saturated pixels
# 2025-07-10 11:42:52,533 - stpipe.SaturationStep - INFO - Detected 0 A/D floor pixels
# 2025-07-10 11:42:52,538 - stpipe.SaturationStep - INFO - Results used CRDS context: jwst_1322.pmap
# 2025-07-10 11:42:52,539 - stpipe.SaturationStep - INFO - Step SaturationStep done
# 2025-07-10 11:42:52,539 - stpipe - INFO - Results used jwst version: 1.17.1
# 2025-07-10 11:42:52.539 - exoTEDRF - WARNING - ResetStep not supported for NIRSpec/PRISM.
# 2025-07-10 11:42:52.555 - exoTEDRF - WARNING - Setting "save_results=False" can be memory intensive.
# 2025-07-10 11:42:52,556 - stpipe.SuperBiasStep - INFO - SuperBiasStep instance created.
# 2025-07-10 11:42:52,564 - stpipe.SuperBiasStep - INFO - SuperBiasStep instance created.
# 2025-07-10 11:42:52,753 - stpipe.SuperBiasStep - INFO - Step SuperBiasStep running with args (<RampModel(60, 70, 32, 2048) from jw01366003001_04101_00001-seg001_nrs1_uncal.fits>,).
# 2025-07-10 11:42:52,755 - stpipe.SuperBiasStep - INFO - Step SuperBiasStep parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ./pipeline_outputs_directory/Stage1/
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: False
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
# 2025-07-10 11:42:52,768 - stpipe.SuperBiasStep - INFO - Using SUPERBIAS reference file /data/pascal/exoTEDRF_fork/Optimize_WASP39b/crds_cache/references/jwst/nirspec/jwst_nirspec_superbias_0427.fits
# 2025-07-10 11:42:55,334 - stpipe.SuperBiasStep - INFO - Results used CRDS context: jwst_1322.pmap
# 2025-07-10 11:42:55,334 - stpipe.SuperBiasStep - INFO - Step SuperBiasStep done
# 2025-07-10 11:42:55,334 - stpipe - INFO - Results used jwst version: 1.17.1
# 2025-07-10 11:42:55.334 - exoTEDRF - WARNING - RefPixStep not supported for NIRSpec/PRISM.
# 2025-07-10 11:42:55.351 - exoTEDRF - WARNING - Setting "save_results=False" can be memory intensive.
# 2025-07-10 11:42:55,352 - stpipe.DarkCurrentStep - INFO - DarkCurrentStep instance created.
# 2025-07-10 11:42:55,359 - CRDS - ERROR -  Error determining best reference for 'pars-darkcurrentstep'  =   No match found.
# 2025-07-10 11:42:55,360 - stpipe.DarkCurrentStep - INFO - DarkCurrentStep instance created.
# 2025-07-10 11:42:55,539 - stpipe.DarkCurrentStep - INFO - Step DarkCurrentStep running with args (<RampModel(60, 70, 32, 2048) from jw01366003001_04101_00001-seg001_nrs1_uncal.fits>,).
# 2025-07-10 11:42:55,540 - stpipe.DarkCurrentStep - INFO - Step DarkCurrentStep parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ./pipeline_outputs_directory/Stage1/
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: False
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   dark_output: None
#   average_dark_current: None
# 2025-07-10 11:42:55,554 - stpipe.DarkCurrentStep - INFO - Using DARK reference file /data/pascal/exoTEDRF_fork/Optimize_WASP39b/crds_cache/references/jwst/nirspec/jwst_nirspec_dark_0438.fits
# 2025-07-10 11:42:56,739 - stpipe.DarkCurrentStep - INFO - Science data nints=60, ngroups=70, nframes=1, groupgap=0
# 2025-07-10 11:42:56,739 - stpipe.DarkCurrentStep - INFO - Dark data nints=1, ngroups=70, nframes=1, groupgap=0
# 2025-07-10 11:42:58,294 - stpipe.DarkCurrentStep - INFO - Results used CRDS context: jwst_1322.pmap
# 2025-07-10 11:42:58,294 - stpipe.DarkCurrentStep - INFO - Step DarkCurrentStep done
# 2025-07-10 11:42:58,294 - stpipe - INFO - Results used jwst version: 1.17.1
# 2025-07-10 11:42:58.315 - exoTEDRF - WARNING - Setting "save_results=False" can be memory intensive.
# 2025-07-10 11:42:58.315 - exoTEDRF - INFO - OneOverFStep instance created.
# 2025-07-10 11:42:58.315 - exoTEDRF - INFO - Creating reference deep stack.
# 2025-07-10 11:43:01.485 - exoTEDRF - INFO - No centroids provided, locating trace positions.
# 2025-07-10 11:43:01.507 - exoTEDRF - INFO - Starting 1/f correction step using the median method.
# 2025-07-10 11:43:01.507 - exoTEDRF - INFO - Processing file jw01366003001_04101_00001-seg001_nrs1_uncal.fits.
# 2025-07-10 11:43:01.507 - exoTEDRF - INFO - Unpacking centroids.
# 2025-07-10 11:43:01.507 - exoTEDRF - WARNING - Dimension of passed centroids do not match data frame dimensions. New centroids will be calculated.
# 2025-07-10 11:43:01.566 - exoTEDRF - WARNING - No outlier map passed, ignoring outliers.
# 2025-07-10 11:43:01.577 - exoTEDRF - INFO - Constructing trace mask.
# 2025-07-10 11:43:01.590 - exoTEDRF - INFO - Flagging additional outliers.
# 2025-07-10 11:43:01.813 - exoTEDRF - INFO - Starting full frame correction.
# 100%|███████████████████████████████████████████| 60/60 [00:03<00:00, 18.49it/s]
# 2025-07-10 11:43:05.564 - exoTEDRF - INFO - Step OneOverFStep done.
# 2025-07-10 11:43:05.570 - exoTEDRF - WARNING - Setting "save_results=False" can be memory intensive.
# 2025-07-10 11:43:05,571 - stpipe.LinearityStep - INFO - LinearityStep instance created.
# 2025-07-10 11:43:05,579 - stpipe.LinearityStep - INFO - LinearityStep instance created.
# 2025-07-10 11:43:05,764 - stpipe.LinearityStep - INFO - Step LinearityStep running with args (<RampModel(60, 70, 32, 2048) from jw01366003001_04101_00001-seg001_nrs1_uncal.fits>,).
# 2025-07-10 11:43:05,766 - stpipe.LinearityStep - INFO - Step LinearityStep parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ./pipeline_outputs_directory/Stage1/
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: False
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
# 2025-07-10 11:43:05,780 - stpipe.LinearityStep - INFO - Using Linearity reference file /data/pascal/exoTEDRF_fork/Optimize_WASP39b/crds_cache/references/jwst/nirspec/jwst_nirspec_linearity_0024.fits
# 2025-07-10 11:43:05,802 - stpipe.LinearityStep - WARNING - Keyword BAD_LIN_CORR does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-07-10 11:43:08,203 - stpipe.LinearityStep - INFO - Results used CRDS context: jwst_1322.pmap
# 2025-07-10 11:43:08,203 - stpipe.LinearityStep - INFO - Step LinearityStep done
# 2025-07-10 11:43:08,203 - stpipe - INFO - Results used jwst version: 1.17.1
# 2025-07-10 11:43:08.229 - exoTEDRF - INFO - Starting time-domain jump detection step.
# 2025-07-10 11:43:08.229 - exoTEDRF - INFO - Processing file jw01366003001_04101_00001-seg001_nrs1_uncal.fits.
# 100%|███████████████████████████████████████████| 70/70 [01:34<00:00,  1.36s/it]
# 2025-07-10 11:44:43.253 - exoTEDRF - INFO - 363495 jumps flagged
# 2025-07-10 11:44:43.253 - exoTEDRF - INFO - and 0 interpolated
# 2025-07-10 11:44:43.255 - exoTEDRF - INFO - Done
# 2025-07-10 11:44:43.259 - exoTEDRF - INFO - Step JumpStep done.
# 2025-07-10 11:44:43,267 - stpipe.RampFitStep - INFO - RampFitStep instance created.
# 2025-07-10 11:44:43,275 - stpipe.RampFitStep - INFO - RampFitStep instance created.
# 2025-07-10 11:44:43,473 - stpipe.RampFitStep - INFO - Step RampFitStep running with args (<RampModel(60, 70, 32, 2048) from jw01366003001_04101_00001-seg001_nrs1_uncal.fits>,).
# 2025-07-10 11:44:43,474 - stpipe.RampFitStep - INFO - Step RampFitStep parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ./pipeline_outputs_directory/Stage1/
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: False
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   algorithm: OLS_C
#   int_name: ''
#   save_opt: False
#   opt_name: ''
#   suppress_one_group: True
#   maximum_cores: quarter
# 2025-07-10 11:44:44,535 - stpipe.RampFitStep - INFO - Using READNOISE reference file: /data/pascal/exoTEDRF_fork/Optimize_WASP39b/crds_cache/references/jwst/nirspec/jwst_nirspec_readnoise_0043.fits
# 2025-07-10 11:44:44,535 - stpipe.RampFitStep - INFO - Using GAIN reference file: /data/pascal/exoTEDRF_fork/Optimize_WASP39b/crds_cache/references/jwst/nirspec/jwst_nirspec_gain_0025.fits
# 2025-07-10 11:44:44,556 - stpipe.RampFitStep - INFO - Extracting gain subarray to match science data
# 2025-07-10 11:44:44,557 - stpipe.RampFitStep - INFO - Extracting readnoise subarray to match science data
# 2025-07-10 11:44:44,557 - stpipe.RampFitStep - INFO - Using algorithm = OLS_C
# 2025-07-10 11:44:44,557 - stpipe.RampFitStep - INFO - Using weighting = optimal
# 2025-07-10 11:44:49,478 - stpipe.RampFitStep - INFO - Number of multiprocessing slices: 8
# 2025-07-10 11:44:49,480 - stpipe.RampFitStep - INFO - Number of processors used for multiprocessing: 8
# 2025-07-10 11:44:57,646 - stpipe - INFO - Ramp Fitting C Time: 4.58551025390625
# 2025-07-10 11:44:58,500 - stpipe - INFO - Ramp Fitting C Time: 4.802242279052734
# 2025-07-10 11:44:58,806 - stpipe - INFO - Ramp Fitting C Time: 3.249657154083252
# 2025-07-10 11:44:59,289 - stpipe - INFO - Ramp Fitting C Time: 4.7194623947143555
# 2025-07-10 11:45:00,106 - stpipe - INFO - Ramp Fitting C Time: 3.5401763916015625
# 2025-07-10 11:45:00,840 - stpipe - INFO - Ramp Fitting C Time: 2.8193464279174805
# 2025-07-10 11:45:00,894 - stpipe - INFO - Ramp Fitting C Time: 3.633603811264038
# 2025-07-10 11:45:02,651 - stpipe - INFO - Ramp Fitting C Time: 3.705420732498169
# 2025-07-10 11:45:03,109 - stpipe.RampFitStep - INFO - Results used CRDS context: jwst_1322.pmap
# 2025-07-10 11:45:03,110 - stpipe.RampFitStep - INFO - Results used CRDS context: jwst_1322.pmap
# 2025-07-10 11:45:03,110 - stpipe.RampFitStep - INFO - Step RampFitStep done
# 2025-07-10 11:45:03,110 - stpipe - INFO - Results used jwst version: 1.17.1
# 2025-07-10 11:45:03.111 - exoTEDRF - INFO - Doing cosmetic NaN interpolation.
# 2025-07-10 11:45:04.683 - exoTEDRF - INFO - Step RampFitStep really done.
# 2025-07-10 11:45:04,696 - stpipe.GainScaleStep - INFO - GainScaleStep instance created.
# 2025-07-10 11:45:04,705 - stpipe.GainScaleStep - INFO - GainScaleStep instance created.
# 2025-07-10 11:45:04,862 - stpipe.GainScaleStep - INFO - Step GainScaleStep running with args (<CubeModel(60, 32, 2048) from jw01366003001_04101_00001-seg001_nrs1_uncal.fits>,).
# 2025-07-10 11:45:04,863 - stpipe.GainScaleStep - INFO - Step GainScaleStep parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ./pipeline_outputs_directory/Stage1/
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: False
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
# 2025-07-10 11:45:04,909 - stpipe.GainScaleStep - INFO - Rescaling by 1.429
# 2025-07-10 11:45:04,922 - stpipe.GainScaleStep - INFO - Step GainScaleStep done
# 2025-07-10 11:45:04,922 - stpipe - INFO - Results used jwst version: 1.17.1
# finish running Stage 1 from Fork
#
#
#
# ###########################################################
#  Step: 2/15 completed
# ###########################################################
#
#
#
#    time_window=5 → J=2.209613 (144.1s)
# Running with params: {'time_window': 7, 'box_size': 15, 'rejection_threshold': 15, 'time_rejection_threshold': 15, 'nirspec_mask_width': 15, 'w1': 1.0, 'w2': 1.0, 'w3': 1.0}
# start running Stage 1 from Fork
# 2025-07-10 11:45:04.932 - exoTEDRF - INFO - **Starting exoTEDRF Stage 1**
# 2025-07-10 11:45:04.932 - exoTEDRF - INFO - Detector level processing
# 2025-07-10 11:45:04.945 - exoTEDRF - WARNING - Setting "save_results=False" can be memory intensive.
# 2025-07-10 11:45:04,946 - stpipe.DQInitStep - INFO - DQInitStep instance created.
# 2025-07-10 11:45:04,952 - stpipe.DQInitStep - INFO - DQInitStep instance created.
# 2025-07-10 11:45:05,109 - stpipe.DQInitStep - INFO - Step DQInitStep running with args (<Level1bModel(60, 70, 32, 2048) from jw01366003001_04101_00001-seg001_nrs1_uncal.fits>,).
# 2025-07-10 11:45:05,110 - stpipe.DQInitStep - INFO - Step DQInitStep parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ./pipeline_outputs_directory/Stage1/
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: False
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
# 2025-07-10 11:45:05,126 - stpipe.DQInitStep - INFO - Using MASK reference file /data/pascal/exoTEDRF_fork/Optimize_WASP39b/crds_cache/references/jwst/nirspec/jwst_nirspec_mask_0051.fits
# 2025-07-10 11:45:06,069 - stpipe.DQInitStep - INFO - Extracting mask subarray to match science data
# 2025-07-10 11:45:06,835 - stpipe.DQInitStep - INFO - Results used CRDS context: jwst_1322.pmap
# 2025-07-10 11:45:06,835 - stpipe.DQInitStep - INFO - Step DQInitStep done
# 2025-07-10 11:45:06,835 - stpipe - INFO - Results used jwst version: 1.17.1
# 2025-07-10 11:45:06.835 - exoTEDRF - WARNING - EmiCorrStep not supported for NIRSpec/PRISM.
# 2025-07-10 11:45:06.836 - exoTEDRF - WARNING - Setting "save_results=False" can be memory intensive.
# 2025-07-10 11:45:06,837 - stpipe.SaturationStep - INFO - SaturationStep instance created.
# 2025-07-10 11:45:06,845 - stpipe.SaturationStep - INFO - SaturationStep instance created.
# 2025-07-10 11:45:07,032 - stpipe.SaturationStep - INFO - Step SaturationStep running with args (<RampModel(60, 70, 32, 2048) from jw01366003001_04101_00001-seg001_nrs1_uncal.fits>,).
# 2025-07-10 11:45:07,034 - stpipe.SaturationStep - INFO - Step SaturationStep parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ./pipeline_outputs_directory/Stage1/
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: False
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   n_pix_grow_sat: 1
#   use_readpatt: True
# 2025-07-10 11:45:07,046 - stpipe.SaturationStep - INFO - Using SATURATION reference file /data/pascal/exoTEDRF_fork/Optimize_WASP39b/crds_cache/references/jwst/nirspec/jwst_nirspec_saturation_0028.fits
# 2025-07-10 11:45:07,875 - stpipe.SaturationStep - INFO - Extracting reference file subarray to match science data
# 2025-07-10 11:45:07,882 - stpipe.SaturationStep - INFO - Using read_pattern with nframes 1
# 2025-07-10 11:45:16,658 - stpipe.SaturationStep - INFO - Detected 320 saturated pixels
# 2025-07-10 11:45:16,909 - stpipe.SaturationStep - INFO - Detected 0 A/D floor pixels
# 2025-07-10 11:45:16,914 - stpipe.SaturationStep - INFO - Results used CRDS context: jwst_1322.pmap
# 2025-07-10 11:45:16,914 - stpipe.SaturationStep - INFO - Step SaturationStep done
# 2025-07-10 11:45:16,914 - stpipe - INFO - Results used jwst version: 1.17.1
# 2025-07-10 11:45:16.914 - exoTEDRF - WARNING - ResetStep not supported for NIRSpec/PRISM.
# 2025-07-10 11:45:16.930 - exoTEDRF - WARNING - Setting "save_results=False" can be memory intensive.
# 2025-07-10 11:45:16,932 - stpipe.SuperBiasStep - INFO - SuperBiasStep instance created.
# 2025-07-10 11:45:16,938 - stpipe.SuperBiasStep - INFO - SuperBiasStep instance created.
# 2025-07-10 11:45:17,159 - stpipe.SuperBiasStep - INFO - Step SuperBiasStep running with args (<RampModel(60, 70, 32, 2048) from jw01366003001_04101_00001-seg001_nrs1_uncal.fits>,).
# 2025-07-10 11:45:17,161 - stpipe.SuperBiasStep - INFO - Step SuperBiasStep parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ./pipeline_outputs_directory/Stage1/
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: False
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
# 2025-07-10 11:45:17,172 - stpipe.SuperBiasStep - INFO - Using SUPERBIAS reference file /data/pascal/exoTEDRF_fork/Optimize_WASP39b/crds_cache/references/jwst/nirspec/jwst_nirspec_superbias_0427.fits
# 2025-07-10 11:45:20,167 - stpipe.SuperBiasStep - INFO - Results used CRDS context: jwst_1322.pmap
# 2025-07-10 11:45:20,167 - stpipe.SuperBiasStep - INFO - Step SuperBiasStep done
# 2025-07-10 11:45:20,167 - stpipe - INFO - Results used jwst version: 1.17.1
# 2025-07-10 11:45:20.167 - exoTEDRF - WARNING - RefPixStep not supported for NIRSpec/PRISM.
# 2025-07-10 11:45:20.187 - exoTEDRF - WARNING - Setting "save_results=False" can be memory intensive.
# 2025-07-10 11:45:20,188 - stpipe.DarkCurrentStep - INFO - DarkCurrentStep instance created.
# 2025-07-10 11:45:20,195 - CRDS - ERROR -  Error determining best reference for 'pars-darkcurrentstep'  =   No match found.
# 2025-07-10 11:45:20,196 - stpipe.DarkCurrentStep - INFO - DarkCurrentStep instance created.
# 2025-07-10 11:45:20,414 - stpipe.DarkCurrentStep - INFO - Step DarkCurrentStep running with args (<RampModel(60, 70, 32, 2048) from jw01366003001_04101_00001-seg001_nrs1_uncal.fits>,).
# 2025-07-10 11:45:20,416 - stpipe.DarkCurrentStep - INFO - Step DarkCurrentStep parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ./pipeline_outputs_directory/Stage1/
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: False
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   dark_output: None
#   average_dark_current: None
# 2025-07-10 11:45:20,427 - stpipe.DarkCurrentStep - INFO - Using DARK reference file /data/pascal/exoTEDRF_fork/Optimize_WASP39b/crds_cache/references/jwst/nirspec/jwst_nirspec_dark_0438.fits
# 2025-07-10 11:45:21,506 - stpipe.DarkCurrentStep - INFO - Science data nints=60, ngroups=70, nframes=1, groupgap=0
# 2025-07-10 11:45:21,506 - stpipe.DarkCurrentStep - INFO - Dark data nints=1, ngroups=70, nframes=1, groupgap=0
# 2025-07-10 11:45:23,056 - stpipe.DarkCurrentStep - INFO - Results used CRDS context: jwst_1322.pmap
# 2025-07-10 11:45:23,056 - stpipe.DarkCurrentStep - INFO - Step DarkCurrentStep done
# 2025-07-10 11:45:23,056 - stpipe - INFO - Results used jwst version: 1.17.1
# 2025-07-10 11:45:23.078 - exoTEDRF - WARNING - Setting "save_results=False" can be memory intensive.
# 2025-07-10 11:45:23.078 - exoTEDRF - INFO - OneOverFStep instance created.
# 2025-07-10 11:45:23.079 - exoTEDRF - INFO - Creating reference deep stack.
# 2025-07-10 11:45:26.948 - exoTEDRF - INFO - No centroids provided, locating trace positions.
# 2025-07-10 11:45:26.972 - exoTEDRF - INFO - Starting 1/f correction step using the median method.
# 2025-07-10 11:45:26.972 - exoTEDRF - INFO - Processing file jw01366003001_04101_00001-seg001_nrs1_uncal.fits.
# 2025-07-10 11:45:26.972 - exoTEDRF - INFO - Unpacking centroids.
# 2025-07-10 11:45:26.972 - exoTEDRF - WARNING - Dimension of passed centroids do not match data frame dimensions. New centroids will be calculated.
# 2025-07-10 11:45:27.050 - exoTEDRF - WARNING - No outlier map passed, ignoring outliers.
# 2025-07-10 11:45:27.060 - exoTEDRF - INFO - Constructing trace mask.
# 2025-07-10 11:45:27.072 - exoTEDRF - INFO - Flagging additional outliers.
# 2025-07-10 11:45:27.292 - exoTEDRF - INFO - Starting full frame correction.
# 100%|███████████████████████████████████████████| 60/60 [00:03<00:00, 19.34it/s]
# 2025-07-10 11:45:30.855 - exoTEDRF - INFO - Step OneOverFStep done.
# 2025-07-10 11:45:30.863 - exoTEDRF - WARNING - Setting "save_results=False" can be memory intensive.
# 2025-07-10 11:45:30,865 - stpipe.LinearityStep - INFO - LinearityStep instance created.
# 2025-07-10 11:45:30,871 - stpipe.LinearityStep - INFO - LinearityStep instance created.
# 2025-07-10 11:45:31,084 - stpipe.LinearityStep - INFO - Step LinearityStep running with args (<RampModel(60, 70, 32, 2048) from jw01366003001_04101_00001-seg001_nrs1_uncal.fits>,).
# 2025-07-10 11:45:31,086 - stpipe.LinearityStep - INFO - Step LinearityStep parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ./pipeline_outputs_directory/Stage1/
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: False
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
# 2025-07-10 11:45:31,097 - stpipe.LinearityStep - INFO - Using Linearity reference file /data/pascal/exoTEDRF_fork/Optimize_WASP39b/crds_cache/references/jwst/nirspec/jwst_nirspec_linearity_0024.fits
# 2025-07-10 11:45:31,120 - stpipe.LinearityStep - WARNING - Keyword BAD_LIN_CORR does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-07-10 11:45:33,283 - stpipe.LinearityStep - INFO - Results used CRDS context: jwst_1322.pmap
# 2025-07-10 11:45:33,283 - stpipe.LinearityStep - INFO - Step LinearityStep done
# 2025-07-10 11:45:33,283 - stpipe - INFO - Results used jwst version: 1.17.1
# 2025-07-10 11:45:33.307 - exoTEDRF - INFO - Starting time-domain jump detection step.
# 2025-07-10 11:45:33.307 - exoTEDRF - INFO - Processing file jw01366003001_04101_00001-seg001_nrs1_uncal.fits.
# 100%|███████████████████████████████████████████| 70/70 [01:40<00:00,  1.44s/it]
# 2025-07-10 11:47:13.999 - exoTEDRF - INFO - 361363 jumps flagged
# 2025-07-10 11:47:13.999 - exoTEDRF - INFO - and 0 interpolated
# 2025-07-10 11:47:14.000 - exoTEDRF - INFO - Done
# 2025-07-10 11:47:14.003 - exoTEDRF - INFO - Step JumpStep done.
# 2025-07-10 11:47:14,014 - stpipe.RampFitStep - INFO - RampFitStep instance created.
# 2025-07-10 11:47:14,021 - stpipe.RampFitStep - INFO - RampFitStep instance created.
# 2025-07-10 11:47:14,220 - stpipe.RampFitStep - INFO - Step RampFitStep running with args (<RampModel(60, 70, 32, 2048) from jw01366003001_04101_00001-seg001_nrs1_uncal.fits>,).
# 2025-07-10 11:47:14,222 - stpipe.RampFitStep - INFO - Step RampFitStep parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ./pipeline_outputs_directory/Stage1/
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: False
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   algorithm: OLS_C
#   int_name: ''
#   save_opt: False
#   opt_name: ''
#   suppress_one_group: True
#   maximum_cores: quarter
# 2025-07-10 11:47:15,266 - stpipe.RampFitStep - INFO - Using READNOISE reference file: /data/pascal/exoTEDRF_fork/Optimize_WASP39b/crds_cache/references/jwst/nirspec/jwst_nirspec_readnoise_0043.fits
# 2025-07-10 11:47:15,266 - stpipe.RampFitStep - INFO - Using GAIN reference file: /data/pascal/exoTEDRF_fork/Optimize_WASP39b/crds_cache/references/jwst/nirspec/jwst_nirspec_gain_0025.fits
# 2025-07-10 11:47:15,287 - stpipe.RampFitStep - INFO - Extracting gain subarray to match science data
# 2025-07-10 11:47:15,287 - stpipe.RampFitStep - INFO - Extracting readnoise subarray to match science data
# 2025-07-10 11:47:15,287 - stpipe.RampFitStep - INFO - Using algorithm = OLS_C
# 2025-07-10 11:47:15,287 - stpipe.RampFitStep - INFO - Using weighting = optimal
# 2025-07-10 11:47:20,352 - stpipe.RampFitStep - INFO - Number of multiprocessing slices: 8
# 2025-07-10 11:47:20,354 - stpipe.RampFitStep - INFO - Number of processors used for multiprocessing: 8
# 2025-07-10 11:47:28,716 - stpipe - INFO - Ramp Fitting C Time: 4.293384552001953
# 2025-07-10 11:47:29,619 - stpipe - INFO - Ramp Fitting C Time: 4.459812641143799
# 2025-07-10 11:47:30,459 - stpipe - INFO - Ramp Fitting C Time: 4.719165086746216
# 2025-07-10 11:47:30,610 - stpipe - INFO - Ramp Fitting C Time: 4.244132995605469
# 2025-07-10 11:47:31,896 - stpipe - INFO - Ramp Fitting C Time: 4.572738885879517
# 2025-07-10 11:47:33,151 - stpipe - INFO - Ramp Fitting C Time: 4.920754671096802
# 2025-07-10 11:47:34,638 - stpipe - INFO - Ramp Fitting C Time: 4.697622299194336
# 2025-07-10 11:47:34,679 - stpipe - INFO - Ramp Fitting C Time: 5.5201897621154785
# 2025-07-10 11:47:36,130 - stpipe.RampFitStep - INFO - Results used CRDS context: jwst_1322.pmap
# 2025-07-10 11:47:36,131 - stpipe.RampFitStep - INFO - Results used CRDS context: jwst_1322.pmap
# 2025-07-10 11:47:36,131 - stpipe.RampFitStep - INFO - Step RampFitStep done
# 2025-07-10 11:47:36,132 - stpipe - INFO - Results used jwst version: 1.17.1
# 2025-07-10 11:47:36.132 - exoTEDRF - INFO - Doing cosmetic NaN interpolation.
# 2025-07-10 11:47:37.706 - exoTEDRF - INFO - Step RampFitStep really done.
# 2025-07-10 11:47:37,719 - stpipe.GainScaleStep - INFO - GainScaleStep instance created.
# 2025-07-10 11:47:37,727 - stpipe.GainScaleStep - INFO - GainScaleStep instance created.
# 2025-07-10 11:47:37,920 - stpipe.GainScaleStep - INFO - Step GainScaleStep running with args (<CubeModel(60, 32, 2048) from jw01366003001_04101_00001-seg001_nrs1_uncal.fits>,).
# 2025-07-10 11:47:37,921 - stpipe.GainScaleStep - INFO - Step GainScaleStep parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ./pipeline_outputs_directory/Stage1/
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: False
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
# 2025-07-10 11:47:37,968 - stpipe.GainScaleStep - INFO - Rescaling by 1.429
# 2025-07-10 11:47:37,982 - stpipe.GainScaleStep - INFO - Step GainScaleStep done
# 2025-07-10 11:47:37,982 - stpipe - INFO - Results used jwst version: 1.17.1
# finish running Stage 1 from Fork
#
#
#
# ###########################################################
#  Step: 3/15 completed
# ###########################################################
#
#
#
#    time_window=7 → J=0.811854 (153.1s)
# ✔→ Best time_window = 7 (J=0.811854, dt=153.1s)
#
# → Optimizing box_size (others fixed = {{'time_window': 7, 'rejection_threshold': 15, 'time_rejection_threshold': 15, 'nirspec_mask_width': 15, 'w1': 1.0, 'w2': 1.0, 'w3': 1.0}})
# Running with params: {'time_window': 7, 'box_size': 10, 'rejection_threshold': 15, 'time_rejection_threshold': 15, 'nirspec_mask_width': 15, 'w1': 1.0, 'w2': 1.0, 'w3': 1.0}
# start running Stage 1 from Fork
# 2025-07-10 11:47:37.992 - exoTEDRF - INFO - **Starting exoTEDRF Stage 1**
# 2025-07-10 11:47:37.992 - exoTEDRF - INFO - Detector level processing
# 2025-07-10 11:47:38.009 - exoTEDRF - WARNING - Setting "save_results=False" can be memory intensive.
# 2025-07-10 11:47:38,011 - stpipe.DQInitStep - INFO - DQInitStep instance created.
# 2025-07-10 11:47:38,017 - stpipe.DQInitStep - INFO - DQInitStep instance created.
# 2025-07-10 11:47:38,219 - stpipe.DQInitStep - INFO - Step DQInitStep running with args (<Level1bModel(60, 70, 32, 2048) from jw01366003001_04101_00001-seg001_nrs1_uncal.fits>,).
# 2025-07-10 11:47:38,220 - stpipe.DQInitStep - INFO - Step DQInitStep parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ./pipeline_outputs_directory/Stage1/
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: False
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
# 2025-07-10 11:47:38,237 - stpipe.DQInitStep - INFO - Using MASK reference file /data/pascal/exoTEDRF_fork/Optimize_WASP39b/crds_cache/references/jwst/nirspec/jwst_nirspec_mask_0051.fits
# 2025-07-10 11:47:39,243 - stpipe.DQInitStep - INFO - Extracting mask subarray to match science data
# 2025-07-10 11:47:39,931 - stpipe.DQInitStep - INFO - Results used CRDS context: jwst_1322.pmap
# 2025-07-10 11:47:39,931 - stpipe.DQInitStep - INFO - Step DQInitStep done
# 2025-07-10 11:47:39,931 - stpipe - INFO - Results used jwst version: 1.17.1
# 2025-07-10 11:47:39.931 - exoTEDRF - WARNING - EmiCorrStep not supported for NIRSpec/PRISM.
# 2025-07-10 11:47:39.931 - exoTEDRF - WARNING - Setting "save_results=False" can be memory intensive.
# 2025-07-10 11:47:39,932 - stpipe.SaturationStep - INFO - SaturationStep instance created.
# 2025-07-10 11:47:39,941 - stpipe.SaturationStep - INFO - SaturationStep instance created.
# 2025-07-10 11:47:40,148 - stpipe.SaturationStep - INFO - Step SaturationStep running with args (<RampModel(60, 70, 32, 2048) from jw01366003001_04101_00001-seg001_nrs1_uncal.fits>,).
# 2025-07-10 11:47:40,152 - stpipe.SaturationStep - INFO - Step SaturationStep parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ./pipeline_outputs_directory/Stage1/
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: False
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   n_pix_grow_sat: 1
#   use_readpatt: True
# 2025-07-10 11:47:40,169 - stpipe.SaturationStep - INFO - Using SATURATION reference file /data/pascal/exoTEDRF_fork/Optimize_WASP39b/crds_cache/references/jwst/nirspec/jwst_nirspec_saturation_0028.fits
# 2025-07-10 11:47:41,058 - stpipe.SaturationStep - INFO - Extracting reference file subarray to match science data
# 2025-07-10 11:47:41,065 - stpipe.SaturationStep - INFO - Using read_pattern with nframes 1
# 2025-07-10 11:47:50,350 - stpipe.SaturationStep - INFO - Detected 320 saturated pixels
# 2025-07-10 11:47:50,560 - stpipe.SaturationStep - INFO - Detected 0 A/D floor pixels
# 2025-07-10 11:47:50,564 - stpipe.SaturationStep - INFO - Results used CRDS context: jwst_1322.pmap
# 2025-07-10 11:47:50,565 - stpipe.SaturationStep - INFO - Step SaturationStep done
# 2025-07-10 11:47:50,565 - stpipe - INFO - Results used jwst version: 1.17.1
# 2025-07-10 11:47:50.565 - exoTEDRF - WARNING - ResetStep not supported for NIRSpec/PRISM.
# 2025-07-10 11:47:50.578 - exoTEDRF - WARNING - Setting "save_results=False" can be memory intensive.
# 2025-07-10 11:47:50,579 - stpipe.SuperBiasStep - INFO - SuperBiasStep instance created.
# 2025-07-10 11:47:50,587 - stpipe.SuperBiasStep - INFO - SuperBiasStep instance created.
# 2025-07-10 11:47:50,790 - stpipe.SuperBiasStep - INFO - Step SuperBiasStep running with args (<RampModel(60, 70, 32, 2048) from jw01366003001_04101_00001-seg001_nrs1_uncal.fits>,).
# 2025-07-10 11:47:50,791 - stpipe.SuperBiasStep - INFO - Step SuperBiasStep parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ./pipeline_outputs_directory/Stage1/
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: False
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
# 2025-07-10 11:47:50,805 - stpipe.SuperBiasStep - INFO - Using SUPERBIAS reference file /data/pascal/exoTEDRF_fork/Optimize_WASP39b/crds_cache/references/jwst/nirspec/jwst_nirspec_superbias_0427.fits
# 2025-07-10 11:47:53,349 - stpipe.SuperBiasStep - INFO - Results used CRDS context: jwst_1322.pmap
# 2025-07-10 11:47:53,349 - stpipe.SuperBiasStep - INFO - Step SuperBiasStep done
# 2025-07-10 11:47:53,349 - stpipe - INFO - Results used jwst version: 1.17.1
# 2025-07-10 11:47:53.349 - exoTEDRF - WARNING - RefPixStep not supported for NIRSpec/PRISM.
# 2025-07-10 11:47:53.363 - exoTEDRF - WARNING - Setting "save_results=False" can be memory intensive.
# 2025-07-10 11:47:53,364 - stpipe.DarkCurrentStep - INFO - DarkCurrentStep instance created.
# 2025-07-10 11:47:53,371 - CRDS - ERROR -  Error determining best reference for 'pars-darkcurrentstep'  =   No match found.
# 2025-07-10 11:47:53,372 - stpipe.DarkCurrentStep - INFO - DarkCurrentStep instance created.
# 2025-07-10 11:47:53,567 - stpipe.DarkCurrentStep - INFO - Step DarkCurrentStep running with args (<RampModel(60, 70, 32, 2048) from jw01366003001_04101_00001-seg001_nrs1_uncal.fits>,).
# 2025-07-10 11:47:53,569 - stpipe.DarkCurrentStep - INFO - Step DarkCurrentStep parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ./pipeline_outputs_directory/Stage1/
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: False
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   dark_output: None
#   average_dark_current: None
# ...
# 2025-07-10 12:10:15.470 - exoTEDRF - WARNING - RefPixStep not supported for NIRSpec/PRISM.
# 2025-07-10 12:10:15.484 - exoTEDRF - WARNING - Setting "save_results=False" can be memory intensive.
# 2025-07-10 12:10:15,485 - stpipe.DarkCurrentStep - INFO - DarkCurrentStep instance created.
# 2025-07-10 12:10:15,492 - CRDS - ERROR -  Error determining best reference for 'pars-darkcurrentstep'  =   No match found.
# 2025-07-10 12:10:15,493 - stpipe.DarkCurrentStep - INFO - DarkCurrentStep instance created.
# 2025-07-10 12:10:15,657 - stpipe.DarkCurrentStep - INFO - Step DarkCurrentStep running with args (<RampModel(60, 70, 32, 2048) from jw01366003001_04101_00001-seg001_nrs1_uncal.fits>,).
# 2025-07-10 12:10:15,659 - stpipe.DarkCurrentStep - INFO - Step DarkCurrentStep parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ./pipeline_outputs_directory/Stage1/
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: False
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   dark_output: None
#   average_dark_current: None
# 2025-07-10 12:10:15,670 - stpipe.DarkCurrentStep - INFO - Using DARK reference file /data/pascal/exoTEDRF_fork/Optimize_WASP39b/crds_cache/references/jwst/nirspec/jwst_nirspec_dark_0438.fits
# 2025-07-10 12:10:16,682 - stpipe.DarkCurrentStep - INFO - Science data nints=60, ngroups=70, nframes=1, groupgap=0
# 2025-07-10 12:10:16,682 - stpipe.DarkCurrentStep - INFO - Dark data nints=1, ngroups=70, nframes=1, groupgap=0
# 2025-07-10 12:10:18,091 - stpipe.DarkCurrentStep - INFO - Results used CRDS context: jwst_1322.pmap
# 2025-07-10 12:10:18,091 - stpipe.DarkCurrentStep - INFO - Step DarkCurrentStep done
# 2025-07-10 12:10:18,091 - stpipe - INFO - Results used jwst version: 1.17.1
# 2025-07-10 12:10:18.112 - exoTEDRF - WARNING - Setting "save_results=False" can be memory intensive.
# 2025-07-10 12:10:18.112 - exoTEDRF - INFO - OneOverFStep instance created.
# 2025-07-10 12:10:18.112 - exoTEDRF - INFO - Creating reference deep stack.
# 2025-07-10 12:10:21.601 - exoTEDRF - INFO - No centroids provided, locating trace positions.
# 2025-07-10 12:10:21.622 - exoTEDRF - INFO - Starting 1/f correction step using the median method.
# 2025-07-10 12:10:21.623 - exoTEDRF - INFO - Processing file jw01366003001_04101_00001-seg001_nrs1_uncal.fits.
# 2025-07-10 12:10:21.623 - exoTEDRF - INFO - Unpacking centroids.
# 2025-07-10 12:10:21.623 - exoTEDRF - WARNING - Dimension of passed centroids do not match data frame dimensions. New centroids will be calculated.
# 2025-07-10 12:10:21.683 - exoTEDRF - WARNING - No outlier map passed, ignoring outliers.
# 2025-07-10 12:10:21.694 - exoTEDRF - INFO - Constructing trace mask.
# 2025-07-10 12:10:21.708 - exoTEDRF - INFO - Flagging additional outliers.
# 2025-07-10 12:10:21.917 - exoTEDRF - INFO - Starting full frame correction.
# 100%|███████████████████████████████████████████| 60/60 [00:03<00:00, 17.98it/s]
# 2025-07-10 12:10:25.706 - exoTEDRF - INFO - Step OneOverFStep done.
# 2025-07-10 12:10:25.714 - exoTEDRF - WARNING - Setting "save_results=False" can be memory intensive.
# 2025-07-10 12:10:25,715 - stpipe.LinearityStep - INFO - LinearityStep instance created.
# 2025-07-10 12:10:25,721 - stpipe.LinearityStep - INFO - LinearityStep instance created.
# 2025-07-10 12:10:25,899 - stpipe.LinearityStep - INFO - Step LinearityStep running with args (<RampModel(60, 70, 32, 2048) from jw01366003001_04101_00001-seg001_nrs1_uncal.fits>,).
# 2025-07-10 12:10:25,900 - stpipe.LinearityStep - INFO - Step LinearityStep parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ./pipeline_outputs_directory/Stage1/
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: False
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
# 2025-07-10 12:10:25,913 - stpipe.LinearityStep - INFO - Using Linearity reference file /data/pascal/exoTEDRF_fork/Optimize_WASP39b/crds_cache/references/jwst/nirspec/jwst_nirspec_linearity_0024.fits
# 2025-07-10 12:10:25,935 - stpipe.LinearityStep - WARNING - Keyword BAD_LIN_CORR does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-07-10 12:10:28,018 - stpipe.LinearityStep - INFO - Results used CRDS context: jwst_1322.pmap
# 2025-07-10 12:10:28,018 - stpipe.LinearityStep - INFO - Step LinearityStep done
# 2025-07-10 12:10:28,018 - stpipe - INFO - Results used jwst version: 1.17.1
# 2025-07-10 12:10:28.040 - exoTEDRF - INFO - Starting time-domain jump detection step.
# 2025-07-10 12:10:28.040 - exoTEDRF - INFO - Processing file jw01366003001_04101_00001-seg001_nrs1_uncal.fits.
# 100%|███████████████████████████████████████████| 70/70 [01:38<00:00,  1.41s/it]
# 2025-07-10 12:12:06.608 - exoTEDRF - INFO - 419051 jumps flagged
# 2025-07-10 12:12:06.608 - exoTEDRF - INFO - and 0 interpolated
# 2025-07-10 12:12:06.610 - exoTEDRF - INFO - Done
# 2025-07-10 12:12:06.613 - exoTEDRF - INFO - Step JumpStep done.
# 2025-07-10 12:12:06,621 - stpipe.RampFitStep - INFO - RampFitStep instance created.
# 2025-07-10 12:12:06,628 - stpipe.RampFitStep - INFO - RampFitStep instance created.
# 2025-07-10 12:12:06,802 - stpipe.RampFitStep - INFO - Step RampFitStep running with args (<RampModel(60, 70, 32, 2048) from jw01366003001_04101_00001-seg001_nrs1_uncal.fits>,).
# 2025-07-10 12:12:06,803 - stpipe.RampFitStep - INFO - Step RampFitStep parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ./pipeline_outputs_directory/Stage1/
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: False
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   algorithm: OLS_C
#   int_name: ''
#   save_opt: False
#   opt_name: ''
#   suppress_one_group: True
#   maximum_cores: quarter
# 2025-07-10 12:12:07,824 - stpipe.RampFitStep - INFO - Using READNOISE reference file: /data/pascal/exoTEDRF_fork/Optimize_WASP39b/crds_cache/references/jwst/nirspec/jwst_nirspec_readnoise_0043.fits
# 2025-07-10 12:12:07,824 - stpipe.RampFitStep - INFO - Using GAIN reference file: /data/pascal/exoTEDRF_fork/Optimize_WASP39b/crds_cache/references/jwst/nirspec/jwst_nirspec_gain_0025.fits
# 2025-07-10 12:12:07,844 - stpipe.RampFitStep - INFO - Extracting gain subarray to match science data
# 2025-07-10 12:12:07,844 - stpipe.RampFitStep - INFO - Extracting readnoise subarray to match science data
# 2025-07-10 12:12:07,844 - stpipe.RampFitStep - INFO - Using algorithm = OLS_C
# 2025-07-10 12:12:07,844 - stpipe.RampFitStep - INFO - Using weighting = optimal
# 2025-07-10 12:12:12,199 - stpipe.RampFitStep - INFO - Number of multiprocessing slices: 8
# 2025-07-10 12:12:12,201 - stpipe.RampFitStep - INFO - Number of processors used for multiprocessing: 8
# 2025-07-10 12:12:20,166 - stpipe - INFO - Ramp Fitting C Time: 4.450790643692017
# 2025-07-10 12:12:20,565 - stpipe - INFO - Ramp Fitting C Time: 4.2491796016693115
# 2025-07-10 12:12:21,040 - stpipe - INFO - Ramp Fitting C Time: 4.143493890762329
# 2025-07-10 12:12:21,741 - stpipe - INFO - Ramp Fitting C Time: 4.2768964767456055
# 2025-07-10 12:12:22,105 - stpipe - INFO - Ramp Fitting C Time: 4.0602147579193115
# 2025-07-10 12:12:22,691 - stpipe - INFO - Ramp Fitting C Time: 4.075446128845215
# 2025-07-10 12:12:23,715 - stpipe - INFO - Ramp Fitting C Time: 4.478200912475586
# 2025-07-10 12:12:24,004 - stpipe - INFO - Ramp Fitting C Time: 4.076836585998535
# 2025-07-10 12:12:24,342 - stpipe.RampFitStep - INFO - Results used CRDS context: jwst_1322.pmap
# 2025-07-10 12:12:24,343 - stpipe.RampFitStep - INFO - Results used CRDS context: jwst_1322.pmap
# 2025-07-10 12:12:24,343 - stpipe.RampFitStep - INFO - Step RampFitStep done
# 2025-07-10 12:12:24,343 - stpipe - INFO - Results used jwst version: 1.17.1
# 2025-07-10 12:12:24.343 - exoTEDRF - INFO - Doing cosmetic NaN interpolation.
# 2025-07-10 12:12:25.977 - exoTEDRF - INFO - Step RampFitStep really done.
# 2025-07-10 12:12:25,990 - stpipe.GainScaleStep - INFO - GainScaleStep instance created.
# 2025-07-10 12:12:25,998 - stpipe.GainScaleStep - INFO - GainScaleStep instance created.
# 2025-07-10 12:12:26,172 - stpipe.GainScaleStep - INFO - Step GainScaleStep running with args (<CubeModel(60, 32, 2048) from jw01366003001_04101_00001-seg001_nrs1_uncal.fits>,).
# 2025-07-10 12:12:26,174 - stpipe.GainScaleStep - INFO - Step GainScaleStep parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ./pipeline_outputs_directory/Stage1/
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: False
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
# 2025-07-10 12:12:26,221 - stpipe.GainScaleStep - INFO - Rescaling by 1.429
# 2025-07-10 12:12:26,236 - stpipe.GainScaleStep - INFO - Step GainScaleStep done
# 2025-07-10 12:12:26,236 - stpipe - INFO - Results used jwst version: 1.17.1
# finish running Stage 1 from Fork
#
#
#
# ###########################################################
#  Step: 13/15 completed
# ###########################################################
#
#
#
#    nirspec_mask_width=8 → J=0.068207 (144.9s)
# Running with params: {'time_window': 7, 'box_size': 10, 'rejection_threshold': 10, 'time_rejection_threshold': 10, 'nirspec_mask_width': 15, 'w1': 1.0, 'w2': 1.0, 'w3': 1.0}
# start running Stage 1 from Fork
# 2025-07-10 12:12:26.245 - exoTEDRF - INFO - **Starting exoTEDRF Stage 1**
# 2025-07-10 12:12:26.245 - exoTEDRF - INFO - Detector level processing
# 2025-07-10 12:12:26.257 - exoTEDRF - WARNING - Setting "save_results=False" can be memory intensive.
# 2025-07-10 12:12:26,258 - stpipe.DQInitStep - INFO - DQInitStep instance created.
# 2025-07-10 12:12:26,264 - stpipe.DQInitStep - INFO - DQInitStep instance created.
# 2025-07-10 12:12:26,437 - stpipe.DQInitStep - INFO - Step DQInitStep running with args (<Level1bModel(60, 70, 32, 2048) from jw01366003001_04101_00001-seg001_nrs1_uncal.fits>,).
# 2025-07-10 12:12:26,439 - stpipe.DQInitStep - INFO - Step DQInitStep parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ./pipeline_outputs_directory/Stage1/
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: False
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
# 2025-07-10 12:12:26,456 - stpipe.DQInitStep - INFO - Using MASK reference file /data/pascal/exoTEDRF_fork/Optimize_WASP39b/crds_cache/references/jwst/nirspec/jwst_nirspec_mask_0051.fits
# 2025-07-10 12:12:27,349 - stpipe.DQInitStep - INFO - Extracting mask subarray to match science data
# 2025-07-10 12:12:28,042 - stpipe.DQInitStep - INFO - Results used CRDS context: jwst_1322.pmap
# 2025-07-10 12:12:28,042 - stpipe.DQInitStep - INFO - Step DQInitStep done
# 2025-07-10 12:12:28,042 - stpipe - INFO - Results used jwst version: 1.17.1
# 2025-07-10 12:12:28.042 - exoTEDRF - WARNING - EmiCorrStep not supported for NIRSpec/PRISM.
# 2025-07-10 12:12:28.042 - exoTEDRF - WARNING - Setting "save_results=False" can be memory intensive.
# 2025-07-10 12:12:28,043 - stpipe.SaturationStep - INFO - SaturationStep instance created.
# 2025-07-10 12:12:28,051 - stpipe.SaturationStep - INFO - SaturationStep instance created.
# 2025-07-10 12:12:28,223 - stpipe.SaturationStep - INFO - Step SaturationStep running with args (<RampModel(60, 70, 32, 2048) from jw01366003001_04101_00001-seg001_nrs1_uncal.fits>,).
# 2025-07-10 12:12:28,224 - stpipe.SaturationStep - INFO - Step SaturationStep parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ./pipeline_outputs_directory/Stage1/
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: False
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   n_pix_grow_sat: 1
#   use_readpatt: True
# 2025-07-10 12:12:28,237 - stpipe.SaturationStep - INFO - Using SATURATION reference file /data/pascal/exoTEDRF_fork/Optimize_WASP39b/crds_cache/references/jwst/nirspec/jwst_nirspec_saturation_0028.fits
# 2025-07-10 12:12:29,037 - stpipe.SaturationStep - INFO - Extracting reference file subarray to match science data
# 2025-07-10 12:12:29,043 - stpipe.SaturationStep - INFO - Using read_pattern with nframes 1
# 2025-07-10 12:12:37,840 - stpipe.SaturationStep - INFO - Detected 320 saturated pixels
# 2025-07-10 12:12:38,036 - stpipe.SaturationStep - INFO - Detected 0 A/D floor pixels
# 2025-07-10 12:12:38,040 - stpipe.SaturationStep - INFO - Results used CRDS context: jwst_1322.pmap
# 2025-07-10 12:12:38,040 - stpipe.SaturationStep - INFO - Step SaturationStep done
# 2025-07-10 12:12:38,040 - stpipe - INFO - Results used jwst version: 1.17.1
# 2025-07-10 12:12:38.040 - exoTEDRF - WARNING - ResetStep not supported for NIRSpec/PRISM.
# 2025-07-10 12:12:38.055 - exoTEDRF - WARNING - Setting "save_results=False" can be memory intensive.
# 2025-07-10 12:12:38,056 - stpipe.SuperBiasStep - INFO - SuperBiasStep instance created.
# 2025-07-10 12:12:38,063 - stpipe.SuperBiasStep - INFO - SuperBiasStep instance created.
# 2025-07-10 12:12:38,238 - stpipe.SuperBiasStep - INFO - Step SuperBiasStep running with args (<RampModel(60, 70, 32, 2048) from jw01366003001_04101_00001-seg001_nrs1_uncal.fits>,).
# 2025-07-10 12:12:38,239 - stpipe.SuperBiasStep - INFO - Step SuperBiasStep parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ./pipeline_outputs_directory/Stage1/
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: False
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
# 2025-07-10 12:12:38,252 - stpipe.SuperBiasStep - INFO - Using SUPERBIAS reference file /data/pascal/exoTEDRF_fork/Optimize_WASP39b/crds_cache/references/jwst/nirspec/jwst_nirspec_superbias_0427.fits
# 2025-07-10 12:12:40,787 - stpipe.SuperBiasStep - INFO - Results used CRDS context: jwst_1322.pmap
# 2025-07-10 12:12:40,788 - stpipe.SuperBiasStep - INFO - Step SuperBiasStep done
# 2025-07-10 12:12:40,788 - stpipe - INFO - Results used jwst version: 1.17.1
# 2025-07-10 12:12:40.788 - exoTEDRF - WARNING - RefPixStep not supported for NIRSpec/PRISM.
# 2025-07-10 12:12:40.803 - exoTEDRF - WARNING - Setting "save_results=False" can be memory intensive.
# 2025-07-10 12:12:40,804 - stpipe.DarkCurrentStep - INFO - DarkCurrentStep instance created.
# 2025-07-10 12:12:40,810 - CRDS - ERROR -  Error determining best reference for 'pars-darkcurrentstep'  =   No match found.
# 2025-07-10 12:12:40,811 - stpipe.DarkCurrentStep - INFO - DarkCurrentStep instance created.
# 2025-07-10 12:12:40,985 - stpipe.DarkCurrentStep - INFO - Step DarkCurrentStep running with args (<RampModel(60, 70, 32, 2048) from jw01366003001_04101_00001-seg001_nrs1_uncal.fits>,).
# 2025-07-10 12:12:40,986 - stpipe.DarkCurrentStep - INFO - Step DarkCurrentStep parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ./pipeline_outputs_directory/Stage1/
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: False
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   dark_output: None
#   average_dark_current: None
# 2025-07-10 12:12:40,999 - stpipe.DarkCurrentStep - INFO - Using DARK reference file /data/pascal/exoTEDRF_fork/Optimize_WASP39b/crds_cache/references/jwst/nirspec/jwst_nirspec_dark_0438.fits
# 2025-07-10 12:12:42,033 - stpipe.DarkCurrentStep - INFO - Science data nints=60, ngroups=70, nframes=1, groupgap=0
# 2025-07-10 12:12:42,034 - stpipe.DarkCurrentStep - INFO - Dark data nints=1, ngroups=70, nframes=1, groupgap=0
# 2025-07-10 12:12:43,451 - stpipe.DarkCurrentStep - INFO - Results used CRDS context: jwst_1322.pmap
# 2025-07-10 12:12:43,451 - stpipe.DarkCurrentStep - INFO - Step DarkCurrentStep done
# 2025-07-10 12:12:43,451 - stpipe - INFO - Results used jwst version: 1.17.1
# 2025-07-10 12:12:43.472 - exoTEDRF - WARNING - Setting "save_results=False" can be memory intensive.
# 2025-07-10 12:12:43.472 - exoTEDRF - INFO - OneOverFStep instance created.
# 2025-07-10 12:12:43.472 - exoTEDRF - INFO - Creating reference deep stack.
# 2025-07-10 12:12:47.311 - exoTEDRF - INFO - No centroids provided, locating trace positions.
