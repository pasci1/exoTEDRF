# %%
import os
os.environ.setdefault('CRDS_PATH', os.path.join(os.getcwd(),'Optimize_WASP39b','crds_cache'))
os.environ.setdefault('CRDS_SERVER_URL', 'https://jwst-crds.stsci.edu')
os.environ.setdefault('CRDS_CONTEXT',    'jwst_1322.pmap')
# Out:
# 'jwst_1322.pmap'

# %%
# !time python3 exotedrf/Optimizer_Big_Sweep.py \
    --config Optimize_WASP39b/run_WASP39b.yaml \
    --instrument NIRSPEC
# Out:
# 2025-07-27 08:51:12,692 - stpipe - WARNING - /data/pascal/exoTEDRF_fork/exoenv_fork/lib/python3.10/site-packages/pastasoss/soss_traces.py:10: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_filename
#
# WebbPSF not installed. Profile simulation not available.
# 2025-07-27 08:51:12.716 - exoTEDRF - INFO - [WARN] No files in Optimize_WASP39b/DMS_uncal, globbing *.fits
# 2025-07-27 08:51:12.716 - exoTEDRF - INFO - Using 8 segment(s) from Optimize_WASP39b/DMS_uncal
# 2025-07-27 08:51:15.862 - exoTEDRF - INFO - → Optimizing time_window (fixed-other={time_rejection_threshold:10, nirspec_mask_width:20, space_thresh:15, time_thresh:10, box_size:5, window_size:6, extract_width:6})
# 2025-07-27 08:51:15.862 - exoTEDRF - INFO - Step 1/67: time_window=5
# nints is: 60
#
# ############################################
#  Step: 1/67 starting time_window=5
# ############################################
#
# start running Stage 1 from Fork
# 2025-07-27 08:51:15.863 - exoTEDRF - INFO - **Starting exoTEDRF Stage 1**
# 2025-07-27 08:51:15.863 - exoTEDRF - INFO - Detector level processing
# 2025-07-27 08:51:15.867 - exoTEDRF - WARNING - Setting "save_results=False" can be memory intensive.
# 2025-07-27 08:51:15,870 - stpipe.DQInitStep - INFO - DQInitStep instance created.
# 2025-07-27 08:51:16,281 - stpipe.DQInitStep - INFO - DQInitStep instance created.
# 2025-07-27 08:51:16,486 - stpipe.DQInitStep - INFO - Step DQInitStep running with args (<Level1bModel(60, 70, 32, 2048) from jw01366003001_04101_00001-seg001_nrs1_uncal.fits>,).
# 2025-07-27 08:51:16,487 - stpipe.DQInitStep - INFO - Step DQInitStep parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ./pipeline_outputs_directory/Stage1/
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: False
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
# 2025-07-27 08:51:16,887 - stpipe.DQInitStep - INFO - Using MASK reference file /data/pascal/exoTEDRF_fork/Optimize_WASP39b/crds_cache/references/jwst/nirspec/jwst_nirspec_mask_0051.fits
# 2025-07-27 08:51:17,819 - stpipe.DQInitStep - INFO - Extracting mask subarray to match science data
# 2025-07-27 08:51:18,661 - stpipe.DQInitStep - INFO - Results used CRDS context: jwst_1322.pmap
# 2025-07-27 08:51:18,661 - stpipe.DQInitStep - INFO - Step DQInitStep done
# 2025-07-27 08:51:18,661 - stpipe - INFO - Results used jwst version: 1.17.1
# 2025-07-27 08:51:18.661 - exoTEDRF - WARNING - EmiCorrStep not supported for NIRSpec/PRISM.
# 2025-07-27 08:51:18.662 - exoTEDRF - WARNING - Setting "save_results=False" can be memory intensive.
# 2025-07-27 08:51:18,663 - stpipe.SaturationStep - INFO - SaturationStep instance created.
# 2025-07-27 08:51:18,671 - stpipe.SaturationStep - INFO - SaturationStep instance created.
# 2025-07-27 08:51:18,868 - stpipe.SaturationStep - INFO - Step SaturationStep running with args (<RampModel(60, 70, 32, 2048) from jw01366003001_04101_00001-seg001_nrs1_uncal.fits>,).
# 2025-07-27 08:51:18,869 - stpipe.SaturationStep - INFO - Step SaturationStep parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ./pipeline_outputs_directory/Stage1/
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: False
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   n_pix_grow_sat: 1
#   use_readpatt: True
# 2025-07-27 08:51:18,880 - stpipe.SaturationStep - INFO - Using SATURATION reference file /data/pascal/exoTEDRF_fork/Optimize_WASP39b/crds_cache/references/jwst/nirspec/jwst_nirspec_saturation_0028.fits
# 2025-07-27 08:51:19,696 - stpipe.SaturationStep - INFO - Extracting reference file subarray to match science data
# 2025-07-27 08:51:19,703 - stpipe.SaturationStep - INFO - Using read_pattern with nframes 1
# 2025-07-27 08:51:28,455 - stpipe.SaturationStep - INFO - Detected 320 saturated pixels
# 2025-07-27 08:51:28,686 - stpipe.SaturationStep - INFO - Detected 0 A/D floor pixels
# 2025-07-27 08:51:28,691 - stpipe.SaturationStep - INFO - Results used CRDS context: jwst_1322.pmap
# 2025-07-27 08:51:28,691 - stpipe.SaturationStep - INFO - Step SaturationStep done
# 2025-07-27 08:51:28,691 - stpipe - INFO - Results used jwst version: 1.17.1
# 2025-07-27 08:51:28.691 - exoTEDRF - WARNING - ResetStep not supported for NIRSpec/PRISM.
# 2025-07-27 08:51:28.709 - exoTEDRF - WARNING - Setting "save_results=False" can be memory intensive.
# 2025-07-27 08:51:28,710 - stpipe.SuperBiasStep - INFO - SuperBiasStep instance created.
# 2025-07-27 08:51:28,717 - stpipe.SuperBiasStep - INFO - SuperBiasStep instance created.
# 2025-07-27 08:51:28,915 - stpipe.SuperBiasStep - INFO - Step SuperBiasStep running with args (<RampModel(60, 70, 32, 2048) from jw01366003001_04101_00001-seg001_nrs1_uncal.fits>,).
# 2025-07-27 08:51:28,916 - stpipe.SuperBiasStep - INFO - Step SuperBiasStep parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ./pipeline_outputs_directory/Stage1/
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: False
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
# 2025-07-27 08:51:28,927 - stpipe.SuperBiasStep - INFO - Using SUPERBIAS reference file /data/pascal/exoTEDRF_fork/Optimize_WASP39b/crds_cache/references/jwst/nirspec/jwst_nirspec_superbias_0427.fits
# 2025-07-27 08:51:31,753 - stpipe.SuperBiasStep - INFO - Results used CRDS context: jwst_1322.pmap
# 2025-07-27 08:51:31,753 - stpipe.SuperBiasStep - INFO - Step SuperBiasStep done
# 2025-07-27 08:51:31,753 - stpipe - INFO - Results used jwst version: 1.17.1
# 2025-07-27 08:51:31.753 - exoTEDRF - WARNING - RefPixStep not supported for NIRSpec/PRISM.
# 2025-07-27 08:51:31.773 - exoTEDRF - WARNING - Setting "save_results=False" can be memory intensive.
# 2025-07-27 08:51:31,774 - stpipe.DarkCurrentStep - INFO - DarkCurrentStep instance created.
# 2025-07-27 08:51:31,780 - CRDS - ERROR -  Error determining best reference for 'pars-darkcurrentstep'  =   No match found.
# 2025-07-27 08:51:31,781 - stpipe.DarkCurrentStep - INFO - DarkCurrentStep instance created.
# 2025-07-27 08:51:31,982 - stpipe.DarkCurrentStep - INFO - Step DarkCurrentStep running with args (<RampModel(60, 70, 32, 2048) from jw01366003001_04101_00001-seg001_nrs1_uncal.fits>,).
# 2025-07-27 08:51:31,983 - stpipe.DarkCurrentStep - INFO - Step DarkCurrentStep parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ./pipeline_outputs_directory/Stage1/
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: False
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   dark_output: None
#   average_dark_current: None
# 2025-07-27 08:51:31,994 - stpipe.DarkCurrentStep - INFO - Using DARK reference file /data/pascal/exoTEDRF_fork/Optimize_WASP39b/crds_cache/references/jwst/nirspec/jwst_nirspec_dark_0438.fits
# 2025-07-27 08:51:33,066 - stpipe.DarkCurrentStep - INFO - Science data nints=60, ngroups=70, nframes=1, groupgap=0
# 2025-07-27 08:51:33,066 - stpipe.DarkCurrentStep - INFO - Dark data nints=1, ngroups=70, nframes=1, groupgap=0
# 2025-07-27 08:51:34,455 - stpipe.DarkCurrentStep - INFO - Results used CRDS context: jwst_1322.pmap
# 2025-07-27 08:51:34,455 - stpipe.DarkCurrentStep - INFO - Step DarkCurrentStep done
# 2025-07-27 08:51:34,456 - stpipe - INFO - Results used jwst version: 1.17.1
# 2025-07-27 08:51:34.480 - exoTEDRF - WARNING - Setting "save_results=False" can be memory intensive.
# 2025-07-27 08:51:34.480 - exoTEDRF - INFO - OneOverFStep instance created.
# 2025-07-27 08:51:34.480 - exoTEDRF - INFO - Creating reference deep stack.
# 2025-07-27 08:51:37.953 - exoTEDRF - INFO - No centroids provided, locating trace positions.
# 2025-07-27 08:51:37.976 - exoTEDRF - INFO - Starting 1/f correction step using the median method.
# 2025-07-27 08:51:37.976 - exoTEDRF - INFO - Processing file jw01366003001_04101_00001-seg001_nrs1_uncal.fits.
# 2025-07-27 08:51:37.976 - exoTEDRF - INFO - Unpacking centroids.
# 2025-07-27 08:51:37.976 - exoTEDRF - WARNING - Dimension of passed centroids do not match data frame dimensions. New centroids will be calculated.
# 2025-07-27 08:51:38.031 - exoTEDRF - WARNING - No outlier map passed, ignoring outliers.
# 2025-07-27 08:51:38.038 - exoTEDRF - INFO - Constructing trace mask.
# 2025-07-27 08:51:38.058 - exoTEDRF - INFO - Flagging additional outliers.
# 2025-07-27 08:51:38.271 - exoTEDRF - INFO - Starting full frame correction.
# 100%|███████████████████████████████████████████| 60/60 [00:02<00:00, 21.04it/s]
# 2025-07-27 08:51:41.588 - exoTEDRF - INFO - Step OneOverFStep done.
# 2025-07-27 08:51:41.596 - exoTEDRF - WARNING - Setting "save_results=False" can be memory intensive.
# 2025-07-27 08:51:41,597 - stpipe.LinearityStep - INFO - LinearityStep instance created.
# 2025-07-27 08:51:41,603 - stpipe.LinearityStep - INFO - LinearityStep instance created.
# 2025-07-27 08:51:41,812 - stpipe.LinearityStep - INFO - Step LinearityStep running with args (<RampModel(60, 70, 32, 2048) from jw01366003001_04101_00001-seg001_nrs1_uncal.fits>,).
# 2025-07-27 08:51:41,813 - stpipe.LinearityStep - INFO - Step LinearityStep parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ./pipeline_outputs_directory/Stage1/
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: False
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
# 2025-07-27 08:51:41,825 - stpipe.LinearityStep - INFO - Using Linearity reference file /data/pascal/exoTEDRF_fork/Optimize_WASP39b/crds_cache/references/jwst/nirspec/jwst_nirspec_linearity_0024.fits
# 2025-07-27 08:51:41,848 - stpipe.LinearityStep - WARNING - Keyword BAD_LIN_CORR does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-07-27 08:51:43,948 - stpipe.LinearityStep - INFO - Results used CRDS context: jwst_1322.pmap
# 2025-07-27 08:51:43,948 - stpipe.LinearityStep - INFO - Step LinearityStep done
# 2025-07-27 08:51:43,948 - stpipe - INFO - Results used jwst version: 1.17.1
# 2025-07-27 08:51:43.972 - exoTEDRF - INFO - Starting time-domain jump detection step.
# 2025-07-27 08:51:43.972 - exoTEDRF - INFO - Processing file jw01366003001_04101_00001-seg001_nrs1_uncal.fits.
#   1%|▋                                           | 1/70 [00:01<02:12,  1.92s/it]

# %%
from IPython.display import Javascript

def notify():
    display(Javascript('alert("Notebook cell finished!")'))

notify()

# %%
p
